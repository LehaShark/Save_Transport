# %%
import os
import matplotlib
matplotlib.use('Agg') # No pictures displayed 
import pylab
import librosa
import librosa.display
import numpy as np

sig, fs = librosa.load(r'D:\reposetory\Save_Transport\data\cut\44.1K\1_01.wav')
print(sig.shape)
print(type(sig))
# make pictures name 
save_path = 'test.jpg'

pylab.axis('off') # no axis
pylab.axes([0., 0., 1., 1.], frameon=False, xticks=[], yticks=[]) # Remove the white edge
S = librosa.feature.melspectrogram(y=sig, sr=fs)
librosa.display.specshow(librosa.power_to_db(S, ref=np.max))
pylab.savefig(save_path, bbox_inches=None, pad_inches=0)
pylab.close()
# Out:
# (110682,)
# <class 'numpy.ndarray'>

# %%
import imageio
import numpy
img = imageio.imread(r'D:\reposetory\Save_Transport\main_classifier\test.jpg')
array = numpy.asarray(img)
print(array.shape)
# Out:
# (480, 640, 3)

# %%
from pydub import AudioSegment
import math

class SplitWavAudioMubin():
    def __init__(self, folder, filename):
        self.folder = folder
        self.filename = filename
        self.filepath = folder + '/' + filename
        
        self.audio = AudioSegment.from_wav(self.filepath)
    
    def get_duration(self):
        return self.audio.duration_seconds
    
    def single_split(self, from_min, to_min, split_filename):
        t1 = from_min * 1000
        t2 = to_min * 1000
        split_audio = self.audio[t1:t2]
        split_audio.export('/home/aigaf/Desktop/GitHub/Save_Transport/dataset/train/5sec_cut/' + split_filename, format="wav")
        
    def multiple_split(self, min_per_split):
        total_mins = math.ceil(self.get_duration() / 1)
        for i in range(0, total_mins, min_per_split):
            split_fn = str(i) + '_' + self.filename
            self.single_split(i, i+min_per_split, split_fn)
            print(str(i) + ' Done')
            if i == total_mins - min_per_split:
                print('All splited successfully ' + self.filename)
# Out:
# C:\Users\Alexe\anaconda3\envs\audioClsfy\lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
import os
files = os.listdir("/home/aigaf/Desktop/GitHub/Save_Transport/dataset/train/cut")

folder = '/home/aigaf/Desktop/GitHub/Save_Transport/dataset/train/cut'

for file in files:
    split_wav = SplitWavAudioMubin(folder, file)
    split_wav.multiple_split(min_per_split=1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-1ad925211f68> in <module>
#       1 import os
# ----> 2 files = os.listdir("/home/aigaf/Desktop/GitHub/Save_Transport/dataset/train/cut")
#       3
#       4 folder = '/home/aigaf/Desktop/GitHub/Save_Transport/dataset/train/cut'
#       5
#
# FileNotFoundError: [WinError 3] Системе не удается найти указанный путь: '/home/aigaf/Desktop/GitHub/Save_Transport/dataset/train/cut'
