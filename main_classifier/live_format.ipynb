# %%
import numpy as np
import pyaudio
import time
from tensorflow.keras.models import load_model
import keyboard
import cv2
import io
import wave

import os
import matplotlib
matplotlib.use('Agg') # No pictures displayed 
import pylab
import librosa
import librosa.display
import numpy as np

# %%
def do_spec (record, save_path):
    sig = record
    fs = 44100
    sig, fs = librosa.load(filename, sr=None)
    pylab.figure()
    pylab.axis('off') # no axis
    pylab.axes([0., 0., 1., 1.], frameon=False, xticks=[], yticks=[]) # Remove the white edge
    S = librosa.feature.melspectrogram(y=sig, sr=fs)
    librosa.display.specshow(librosa.power_to_db(S, ref=np.max))
    pylab.savefig(save_path, bbox_inches=None, pad_inches=0)
    pylab.close()

# %%
def do_spec_1 (record):
      
    fig = pylab.figure()
    pylab.axis('off') # no axis
    pylab.axes([0., 0., 1., 1.], frameon=False, xticks=[], yticks=[]) # Remove the white edge
    S = librosa.feature.melspectrogram(y=record, sr=fs)
    librosa.display.specshow(librosa.power_to_db(S, ref=np.max))
    pylab.close()

    return get_img_from_fig(fig)

# %%
def preprocessing_spectrogram(img_arr):
    
    f = cv2.resize(img_arr, (150, 150))
    res = f.reshape(-1, 150, 150, 3)
    
    return res

# %%
def makeNewFormatArr(old_arrays):

    new_array = []
    for array in old_arrays:
        for elem in array:
            new_array.append(elem)

    new_array = np.asarray(new_array)

    return new_array

# %%
    def get_img_from_fig(fig):

        buf = io.BytesIO()
        fig.savefig(buf, format='png')
        buf.seek(0)
        img_arr = np.frombuffer(buf.getvalue(), dtype=np.uint8)
        buf.close()
        img = cv2.imdecode(img_arr, 1)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        return img

# %%
import sounddevice as sd
from scipy.io.wavfile import write
from PIL import Image

fs = 44100  # Sample rate
seconds = 1  # Duration of recording
model = load_model('/home/aigaf/Downloads/Telegram Desktop/new_model.h5')

while(True):
   
    record = sd.rec(int(seconds * fs), samplerate=fs, channels=1)
    sd.wait()  # Wait until recording is finished

    record = makeNewFormatArr(record)
    img_array = do_spec_1(record)
    img_compl = preprocessing_spectrogram(img_array)

    final_result = model.predict(img_compl) # [1., 0.] cut sound

    if (final_result[0][0] == 1):
        print("Разрез бумаги")
    else:
        print("Посторонний шум")
# Out:
# Посторонний шум
# Посторонний шум
# Посторонний шум
# Посторонний шум
# Посторонний шум
# Посторонний шум
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-1bf1a7a87827> in <module>
#      14     record = makeNewFormatArr(record)
#      15     #record = np.asarray(record)
# ---> 16     img_array = do_spec_1(record)
#      17
#      18     img_compl = preprocessing_spectrogram(img_array)
#
# <ipython-input-26-425054b04da8> in do_spec_1(record)
#       6     S = librosa.feature.melspectrogram(y=record, sr=fs)
#       7     librosa.display.specshow(librosa.power_to_db(S, ref=np.max))
# ----> 8     pylab.close()
#       9
#      10     return get_img_from_fig(fig)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in close(fig)
#     677             return
#     678         else:
# --> 679             _pylab_helpers.Gcf.destroy(figManager.num)
#     680     elif fig == 'all':
#     681         _pylab_helpers.Gcf.destroy_all()
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/_pylab_helpers.py in destroy(cls, num)
#      53         del cls.figs[num]
#      54         manager.destroy()
# ---> 55         gc.collect(1)
#      56
#      57     @classmethod
#
# KeyboardInterrupt:
