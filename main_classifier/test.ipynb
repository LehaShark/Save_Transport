# %%
from pydub import AudioSegment
import math
#split audio
class SplitWavAudioMubin():
    def __init__(self, folder, filename):
        self.folder = folder
        self.filename = filename
        self.filepath = folder + '/' + filename
        
        self.audio = AudioSegment.from_wav(self.filepath)
    
    def get_duration(self):
        return self.audio.duration_seconds
    
    def single_split(self, from_min, to_min, split_filename):
        t1 = from_min * 1000
        t2 = to_min * 1000
        split_audio = self.audio[t1:t2]
        split_audio.export(r'D:\reposetory\Save_Transport\test' + split_filename, format="wav")
        
    def multiple_split(self, min_per_split):
        total_mins = math.ceil(self.get_duration() / 1)
        for i in range(0, total_mins, min_per_split):
            split_fn = str(i) + '_' + self.filename
            self.single_split(i, i+min_per_split, split_fn)
            print(str(i) + ' Done')
            if i == total_mins - min_per_split:
                print('All splited successfully ' + self.filename)

# %%
#split audio
import os

folder = r"D:\reposetory\Save_Transport\DATA\cut\44.1K"

files = os.listdir(folder)

for file in files:
    split_wav = SplitWavAudioMubin(folder, file)
    split_wav.multiple_split(min_per_split=1)
# Out:
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# All splited successfully 10_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# All splited successfully 11_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# All splited successfully 12_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# All splited successfully 13_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# All splited successfully 14_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# All splited successfully 15_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# 5 Done
# All splited successfully 16_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# All splited successfully 17_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# All splited successfully 18_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# All splited successfully 19_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# 5 Done
# All splited successfully 1_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# All splited successfully 20_01.wav
# 0 Done
# 1 Done
# All splited successfully 21_01.wav
# 0 Done
# 1 Done
# All splited successfully 22_01.wav
# 0 Done
# 1 Done
# All splited successfully 23_01.wav
# 0 Done
# 1 Done
# 2 Done
# All splited successfully 24_01.wav
# 0 Done
# 1 Done
# All splited successfully 25_01.wav
# 0 Done
# 1 Done
# All splited successfully 26_01.wav
# 0 Done
# 1 Done
# All splited successfully 27_01.wav
# 0 Done
# 1 Done
# All splited successfully 28_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# All splited successfully 29_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# 5 Done
# All splited successfully 2_01.wav
# 0 Done
# 1 Done
# All splited successfully 30_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# All splited successfully 31_01.wav
# 0 Done
# 1 Done
# All splited successfully 32_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# 5 Done
# 6 Done
# 7 Done
# 8 Done
# 9 Done
# All splited successfully 33_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# 5 Done
# All splited successfully 34_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# 5 Done
# 6 Done
# 7 Done
# 8 Done
# 9 Done
# All splited successfully 35_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# 5 Done
# All splited successfully 36_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# 5 Done
# 6 Done
# All splited successfully 37_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# 5 Done
# 6 Done
# 7 Done
# All splited successfully 38_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# 5 Done
# All splited successfully 39_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# 5 Done
# All splited successfully 3_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# 5 Done
# 6 Done
# All splited successfully 40_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# 5 Done
# 6 Done
# All splited successfully 41_01.wav
# 0 Done
# 1 Done
# All splited successfully 42_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# 5 Done
# 6 Done
# All splited successfully 43_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# All splited successfully 44_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# All splited successfully 45_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# All splited successfully 46_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# All splited successfully 47_01.wav
# 0 Done
# 1 Done
# 2 Done
# All splited successfully 48_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# 5 Done
# All splited successfully 49_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# 5 Done
# All splited successfully 4_01.wav
# 0 Done
# 1 Done
# 2 Done
# All splited successfully 50_01.wav
# 0 Done
# 1 Done
# 2 Done
# All splited successfully 51_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# All splited successfully 52_01.wav
# 0 Done
# 1 Done
# 2 Done
# All splited successfully 53_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# 5 Done
# 6 Done
# 7 Done
# 8 Done
# All splited successfully 54_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# All splited successfully 55_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# 5 Done
# All splited successfully 56_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# All splited successfully 57_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# 5 Done
# All splited successfully 58_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# 5 Done
# All splited successfully 59_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# 5 Done
# All splited successfully 5_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# 5 Done
# 6 Done
# All splited successfully 60_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# All splited successfully 6_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# All splited successfully 7_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# All splited successfully 8_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# All splited successfully 9_01.wav

# %%
import numpy as np
import pyaudio
import time
import librosa
import matplotlib.pyplot as plt
import librosa.display
from tensorflow.keras.models import load_model
import keyboard
import cv2

def create_spectrogram(filename, path):
    
    plt.interactive(False)
    clip, sample_rate = librosa.load(filename, sr=None)
    
    fig = plt.figure(figsize=[0.72,0.72])
    ax = fig.add_subplot(111)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_frame_on(False)
    S = librosa.feature.melspectrogram(y=clip, sr=sample_rate)
    librosa.display.specshow(librosa.power_to_db(S, ref=np.max))
    
    plt.savefig(path, dpi=400, bbox_inches='tight',pad_inches=0)
    plt.close()    
    fig.clf()
    plt.close(fig)
    plt.close('all')
    
    return S
    del filename,clip,sample_rate,fig,ax,S

# %%
from glob import *

Data_dir=np.array(glob(r"D:\reposetory\Save_Transport\test\*"))
#%load_ext memory_profiler
#%memit 

i=0
for file in Data_dir[i:i+2000]:
    #Define the filename as is, "name" refers to the JPG, and is split off into the number itself. 
    filename,name = file,file.split('\\')[-1].split('.')[0]
    path = r'D:\reposetory\Save_Transport\one_sec\\' + name + '.jpg'
    sp = create_spectrogram(filename, path)
    print(sp.shape)

# from matplotlib import pyplot as plt 
# plt.imshow(sp, interpolation='nearest') 
# plt.show() 

librosa.display.specshow(librosa.power_to_db(sp, ref=np.max))
#gc.collect()
# Out:
# (128, 87)
# (128, 87)
# (128, 87)
# (128, 87)
# (128, 87)
# (128, 87)
# (128, 87)
# (128, 87)
# (128, 87)
# (128, 87)
# (128, 87)

# %%
clip, sample_rate = librosa.load(filename, sr=None)
print(type(clip))
# Out:
# <class 'numpy.ndarray'>

# %%
# import sounddevice as sd
# from scipy.io.wavfile import write

# fs = 44100  # Sample rate
# seconds = 1  # Duration of recording

# myrecording = sd.rec(int(seconds * fs), samplerate=fs, channels=2)
# print(type(myrecording))
#sd.wait()  # Wait until recording is finished
#write('output.wav', fs, myrecording)  # Save as WAV file
# Out:
# <class 'numpy.ndarray'>
