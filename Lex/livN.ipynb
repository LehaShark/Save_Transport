# %%
import numpy as np
import time
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model
import keyboard
import cv2
import io
import wave

import os
import matplotlib
matplotlib.use('Agg') # No pictures displayed 
import pylab
import librosa
import librosa.display

# %%
def preprocessing_spectrogram(img_arr): 
    
    f = cv2.resize(img_arr, (150, 150))
    res = f.reshape(-1, 150, 150, 3)
    
    return res

# %%
def makeNewFormatArr(old_arrays):

    new_array = []
    for array in old_arrays:
        for elem in array:
            new_array.append(elem)

    new_array = np.asarray(new_array)

    return new_array

# %%
def do_spec (record, save_path):
    sig = record
    fs = 44100
    #sig, fs = librosa.load(filename, sr=None)

    pylab.axis('off') # no axis
    pylab.axes([0., 0., 1., 1.], frameon=False, xticks=[], yticks=[]) # Remove the white edge
    S = librosa.feature.melspectrogram(y=sig, sr=fs)
    librosa.display.specshow(librosa.power_to_db(S, ref=np.max))
    pylab.savefig(save_path, bbox_inches=None, pad_inches=0)
    pylab.close()

# %%
import librosa
import sounddevice as sd
from scipy.io.wavfile import write
from PIL import Image

fs = 44100  # Sample rate
seconds = 1  # Duration of recording

record = sd.rec(int(seconds * fs), samplerate=fs, channels=1)
sd.wait()  # Wait until recording is finished

record = makeNewFormatArr(record)

spectrogram = librosa.feature.melspectrogram(y=record, sr=fs)
print(S.shape)
print(type(S))
librosa.display.specshow(librosa.power_to_db(S, ref=np.max))

img_arr = Image.fromarray(spectrogram, 'RGB')
img_arr.save('dfs.png')
#plt.imsave()
# Out:
# (128, 87)
# <class 'numpy.ndarray'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-c1f390eb8bcb> in <module>
#      19 img_arr = Image.fromarray(spectrogram, 'RGB')
#      20 img_arr.save('dfs.png')
# ---> 21 plt.imsave()
#
# TypeError: imsave() missing 2 required positional arguments: 'fname' and 'arr'

# %%
audio_array, sr = librosa.core.load(audio_file, sr=sample_rate, mono=True)
melspectrogram = librosa.feature.melspectrogram(y=audio_array, sr=sample_rate, S=None, n_fft=window_size, hop_length=hop_length)
