# %%
from pyAudioAnalysis import MidTermFeatures as aF
import os
import numpy as np
from sklearn.svm import SVC
import plotly.graph_objs as go 
import plotly

# %%
from pyAudioAnalysis.audioTrainTest import extract_features_and_train
mt, st = 1.0, 0.05
dirs = ["/home/aigaf/Desktop/audio-classification-master/data/002-Noise", "/home/aigaf/Desktop/audio-classification-master/data/001-Paper"] 
model = extract_features_and_train(dirs, mt, mt, st, st, "svm_rbf", "svm_paper_noise")
# Out:
# Analyzing file 1 of 206: /home/aigaf/Desktop/audio-classification-master/data/002-Noise/1-100032-A-0.wav
# Analyzing file 2 of 206: /home/aigaf/Desktop/audio-classification-master/data/002-Noise/1-100038-A-14.wav
# Analyzing file 3 of 206: /home/aigaf/Desktop/audio-classification-master/data/002-Noise/1-100210-A-36.wav
# Analyzing file 4 of 206: /home/aigaf/Desktop/audio-classification-master/data/002-Noise/1-100210-B-36.wav
# Analyzing file 5 of 206: /home/aigaf/Desktop/audio-classification-master/data/002-Noise/1-101296-A-19.wav
# Analyzing file 6 of 206: /home/aigaf/Desktop/audio-classification-master/data/002-Noise/1-101296-B-19.wav
# Analyzing file 7 of 206: /home/aigaf/Desktop/audio-classification-master/data/002-Noise/1-101336-A-30.wav
# Analyzing file 8 of 206: /home/aigaf/Desktop/audio-classification-master/data/002-Noise/1-101404-A-34.wav
# Analyzing file 9 of 206: /home/aigaf/Desktop/audio-classification-master/data/002-Noise/1-103298-A-9.wav
# ...

# %%
from pyAudioAnalysis import audioTrainTest as aT

directory = "/home/aigaf/Desktop/audio-classification-master/data/001-Paper-1sec/"

files = os.listdir("/home/aigaf/Desktop/audio-classification-master/data/001-Paper-1sec")

for f in files:
    print(f'{f}:')
    c, p, p_nam = aT.file_classification(directory + '/' + f, "svm_paper_noises", "svm_rbf")
    print(f'P({p_nam[0]}={p[0]})')
    print(f'P({p_nam[1]}={p[1]})')
# Out:
# 0_31_01.wav:
# P(002-Noise=0.9756119619087883)
# P(001-Paper=0.024388038091211657)
# 1_60_01.wav:
# P(002-Noise=0.9306981232512695)
# P(001-Paper=0.06930187674873048)
# 2_40_01.wav:
# P(002-Noise=0.962647885714621)
# P(001-Paper=0.037352114285378955)
# 1_19_01.wav:
# P(002-Noise=0.932426992572179)
# P(001-Paper=0.06757300742782085)
# 5_37_01.wav:
# P(002-Noise=0.9873139978333096)
# P(001-Paper=0.012686002166690318)
# 0_60_01.wav:
# P(002-Noise=0.9867365997286772)
# P(001-Paper=0.013263400271322794)
# 8_33_01.wav:
# P(002-Noise=0.023252220889370553)
# P(001-Paper=0.9767477791106294)
# 4_9_01.wav:
# P(002-Noise=0.9877101893154072)
# P(001-Paper=0.012289810684592915)
# 3_46_01.wav:
# P(002-Noise=0.9487160787244908)
# P(001-Paper=0.05128392127550926)
# 4_56_01.wav:
# P(002-Noise=0.9804592300522216)
# P(001-Paper=0.01954076994777844)
# 3_35_01.wav:
# P(002-Noise=0.93980968148478)
# P(001-Paper=0.06019031851522006)
# 3_31_01.wav:
# P(002-Noise=0.9816758888104207)
# ...

# %%
files_to_test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-f5ceb1fd0576> in <module>
# ----> 1 string(files_to_test)
#
# NameError: name 'string' is not defined

# %%
from pydub import AudioSegment
import math

class SplitWavAudioMubin():
    def __init__(self, folder, filename):
        self.folder = folder
        self.filename = filename
        self.filepath = folder + '/' + filename
        
        self.audio = AudioSegment.from_wav(self.filepath)
    
    def get_duration(self):
        return self.audio.duration_seconds
    
    def single_split(self, from_min, to_min, split_filename):
        t1 = from_min * 1000
        t2 = to_min * 1000
        split_audio = self.audio[t1:t2]
        split_audio.export('/home/aigaf/Desktop/audio-classification-master/data/001-Paper-1sec/' + split_filename, format="wav")
        
    def multiple_split(self, min_per_split):
        total_mins = math.ceil(self.get_duration() / 1)
        for i in range(0, total_mins, min_per_split):
            split_fn = str(i) + '_' + self.filename
            self.single_split(i, i+min_per_split, split_fn)
            print(str(i) + ' Done')
            if i == total_mins - min_per_split:
                print('All splited successfully ' + self.filename)

# %%
import os
files = os.listdir("/home/aigaf/Desktop/audio-classification-master/data/001-Paper")

# %%
folder = '/home/aigaf/Desktop/audio-classification-master/data/001-Paper'

for file in files:
    split_wav = SplitWavAudioMubin(folder, file)
    split_wav.multiple_split(min_per_split=1)
# Out:
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# 5 Done
# 6 Done
# All splited successfully 37_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# 5 Done
# 6 Done
# All splited successfully 43_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# 5 Done
# All splited successfully 59_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# 5 Done
# All splited successfully 49_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# 5 Done
# 6 Done
# All splited successfully 40_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# All splited successfully 55_01.wav
# 0 Done
# 1 Done
# All splited successfully 42_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# 5 Done
# 6 Done
# 7 Done
# 8 Done
# 9 Done
# All splited successfully 33_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# 5 Done
# All splited successfully 39_01.wav
# 0 Done
# 1 Done
# 2 Done
# 3 Done
# All splited successfully 46_01.wav
# 0 Done
# 1 Done
# All splited successfully 21_01.wav
# 0 Done
# 1 Done
# 2 Done
# ...

# %%
import sounddevice as sd
from scipy.io.wavfile import write

fs = 44100  # Sample rate
seconds = 1  # Duration of recording

while(True)
    myrecording = sd.rec(int(seconds * fs), samplerate=fs, channels=2)
    sd.wait()  # Wait until recording is finished
    
    #write('output.wav', fs, myrecording) # конверт в wav и сохранение

# %%
# Example7: use trained model from Example6 
# to classify an unknown sample (song)
from pyAudioAnalysis import audioTrainTest as aT
files_to_test = ["data/music/test/classical.00095.au.wav",
                 "data/music/test/metal.00004.au.wav",
                 "data/music/test/rock.00037.au.wav"]
for f in files_to_test:
    print(f'{f}:')
    c, p, p_nam = aT.file_classification(f, "svm_classical_metal","svm_rbf")
    print(f'P({p_nam[0]}={p[0]})')
    print(f'P({p_nam[1]}={p[1]})')
    print()
# Out:
# data/music/test/classical.00095.au.wav:
# fileClassification: input model_name not found!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-b58081f1d107> in <module>
#       8     print(f'{f}:')
#       9     c, p, p_nam = aT.file_classification(f, "svm_classical_metal","svm_rbf")
# ---> 10     print(f'P({p_nam[0]}={p[0]})')
#      11     print(f'P({p_nam[1]}={p[1]})')
#      12     print()
#
# TypeError: 'int' object is not subscriptable

# %%
sales = pd.read_csv("/home/aigaf/Downloads/Hack/sales_history.csv", parse_dates=['sale_dt'])
sales = sales.drop(["Unnamed: 0"],axis=1)
sales = sales.rename(columns={"posid": "storeID", "salerevenuerub": "salesRUB", "skutertiaryid": "orderID", 
                              "sale_dt": "saleData"})

# %%
dateOfPromo = pd.read_excel("/home/aigaf/Downloads/Hack/promo_history.xlsx", parse_dates=['start_dttm', 'end_dttm'])
dateOfPromo = dateOfPromo.drop(["Unnamed: 0", 0],axis=1)
dateOfPromo = dateOfPromo.rename(columns={"promotypeid": "promoID", "chaindiscountvalue": "discount", "skutertiaryid": "orderID", 
                                          "start_dttm": "startDate", "end_dttm": "endDate"})

# %%
dateOfPromo
# Out:
#      startDate    endDate  orderID  promoID  discount
# 0   2019-01-16 2019-01-29     7205       67  0.228495
# 1   2019-01-16 2019-01-29     7234       67  0.239229
# 2   2019-02-13 2019-02-26     7182       70  0.233531
# 3   2019-02-13 2019-02-26     7205       67  0.221040
# 4   2019-02-13 2019-02-26     7234       67  0.216858
# ..         ...        ...      ...      ...       ...
# 98  2021-06-09 2021-06-15     7247       70  0.150000
# 99  2021-06-30 2021-07-06     7189       70  0.300000
# 100 2021-06-30 2021-07-06     7194       70  0.300000
# 101 2021-06-30 2021-07-06     7205       70  0.250000
# 102 2021-06-30 2021-07-06     7234       70  0.250000
#
# [103 rows x 5 columns]

# %% [markdown]
# ### Получаем цену за единицу товара

# %%
price = sales['salesRUB'] / sales['soldpieces']
sales['price'] = price

# %% [markdown]
# ###  Отбираем данные с промоакцией и без

# %%
mask = 0
for i in range(dateOfPromo.shape[0]-1): 
    mask1 = (sales['saleData'] > dateOfPromo['startDate'][i]) & (sales['saleData'] <= dateOfPromo['startDate'][i+1])
    mask = mask | mask1
    
salesWithPromo = sales.loc[mask]
salesNoPromo =  sales.loc[-mask]

# %% [markdown]
# ### Убираю бесконечности и слишком большие значения для цены за товар со скидкой

# %%
quantile = salesWithPromo['price'].quantile(.99999) #Убрал бесконечности и слишком большие значения
mask = (salesWithPromo['price'] < quantile)
quantileWithPromo = salesWithPromo.loc[mask]

print(salesWithPromo.shape[0] - quantileWithPromo.shape[0]) # вывод количества удаленных значений
# Out:
# 187

# %%
quantileWithPromo["price"].max()
# Out:
# 123.49563

# %% [markdown]
# ### Узнаю цены за товары со скидками. В будущем нужно будет учеть и инфляцию

# %%
sns.set(rc={'figure.figsize':(8,10)})

# %%
ax1 = sns.boxplot(x=quantileWithPromo['orderID'], y=quantileWithPromo['price'], data=quantileWithPromo)

# %% [markdown]
# ### Убираю бесконечности и слишком большие значения для цены за товар без скидки

# %%
quantile = salesNoPromo['price'].quantile(.99999) #Убрал бесконечности и слишком большие значения
mask = (salesNoPromo['price'] < quantile) & (salesNoPromo['price'] > 0)
quantileNoPromo = salesNoPromo.loc[mask]

print(salesNoPromo.shape[0] - quantileNoPromo.shape[0]) # вывод количества удаленных значений
# Out:
# 41

# %%
quantileNoPromo["price"].max()
# Out:
# 110.05363692

# %% [markdown]
# ### Узнаю цены за товары со скидками

# %%
sns.boxplot(x=quantileNoPromo['orderID'], y=quantileNoPromo['price'], data=quantileNoPromo)

# %% [markdown]
# ### Анализ магазинов

# %%
mask = (sales['storeID'] == 276130) & (sales['orderID'] == 7182)
storeID = sales.loc[mask]
storeID = storeID.sort_values(by='saleData')
storeID
# Out:
#             salesRUB  soldpieces  orderID  storeID   saleData      price
# 17450     1046.52076          12     7182   276130 2018-04-23  87.210063
# 17449      348.85520           4     7182   276130 2018-04-30  87.213800
# 163842     697.68798           8     7182   276130 2018-05-01  87.210997
# 163841     450.30570           6     7182   276130 2018-05-07  75.050950
# 163843     767.21240          10     7182   276130 2018-05-14  76.721240
# ...              ...         ...      ...      ...        ...        ...
# 15014223   493.96200           5     7182   276130 2020-12-01  98.792400
# 15014224   395.16960           4     7182   276130 2020-12-07  98.792400
# 15014225   395.16960           4     7182   276130 2020-12-14  98.792400
# 15014216   465.45060           7     7182   276130 2020-12-21  66.492943
# 15014217   731.41260          11     7182   276130 2020-12-28  66.492055
#
# [164 rows x 6 columns]

# %%
# Draw Plot
def plot_df(df, x, y, title="", xlabel='Date', ylabel='orderID 7182', dpi=100):
    plt.figure(figsize=(8,4), dpi=dpi)
    plt.plot(x, y, color='tab:red')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)

# %%
plot_df(storeID, x=storeID.saleData, y=storeID.soldpieces, title='Количество продаж в ' + str(276130) + " магазине")

# %%
plot_df(storeID, x=storeID.saleData, y=storeID.price, title='Стоимость товара в ' + str(276130) + " магазине")
